# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv(r"C:\Users\SHIVANI\OneDrive\Attachments\ChurnGuard AI — Customer Churn Prediction & Retention System\customer_churn.csv")

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df = df.drop("customerID", axis=1)

print("Shape after removing customerID:", df.shape)
# Out:
# Shape after removing customerID: (7043, 20)

# %%
df["TotalCharges"] = pd.to_numeric(
    df["TotalCharges"],
    errors="coerce"
)

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df["TotalCharges"] = df["TotalCharges"].fillna(
    df["TotalCharges"].median()
)

# %%
print("Missing TotalCharges:", df["TotalCharges"].isnull().sum())
# Out:
# Missing TotalCharges: 0

# %%
missing = df.isnull().sum()

print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 22

# %%
df = df.drop_duplicates()

print("Shape after removing duplicates:", df.shape)
# Out:
# Shape after removing duplicates: (7021, 20)

# %%
df["Churn"] = df["Churn"].map({
    "No": 0,
    "Yes": 1
})

# %%
print("Final Shape:", df.shape)

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum().sum())
# Out:
# Final Shape: (7021, 20)
#
# Data Types:
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object
#
# Missing Values:
# 0

# %%
categorical_cols = df.select_dtypes(include=["object", "str"]).columns.tolist()
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()

print("Categorical Columns:")
print(categorical_cols)

print("\nNumerical Columns:")
print(numerical_cols)
# Out:
# Categorical Columns:
# ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
#
# Numerical Columns:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
categorical_cols = X.select_dtypes(
    include=["object", "str"]
).columns.tolist()

numerical_cols = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

print("Categorical Features:", categorical_cols)
print("\nNumerical Features:", numerical_cols)
# Out:
# Categorical Features: ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
#
# Numerical Features: ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
from sklearn.model_selection import train_test_split

X = df.drop("Churn", axis=1)
y = df["Churn"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (5616, 19)
# X_test : (1405, 19)
# y_train: (5616,)
# y_test : (1405,)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# %%
categorical_cols = X_train.select_dtypes(
    include=["object", "str"]
).columns.tolist()

numerical_cols = X_train.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

print("Categorical:", categorical_cols)
print("Numerical:", numerical_cols)
# Out:
# Categorical: ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
# Numerical: ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            StandardScaler(),
            numerical_cols
        ),
        (
            "cat",
            OneHotEncoder(
                handle_unknown="ignore",
                sparse_output=False
            ),
            categorical_cols
        )
    ]
)

# %%
X_train_processed = preprocessor.fit_transform(X_train)

X_test_processed = preprocessor.transform(X_test)

print("Processed X_train shape:", X_train_processed.shape)
print("Processed X_test shape:", X_test_processed.shape)
# Out:
# Processed X_train shape: (5616, 45)
# Processed X_test shape: (1405, 45)

# %%
feature_names = preprocessor.get_feature_names_out()

print("Total Features:", len(feature_names))

print("\nFirst 20 Features:")
print(feature_names[:20])
# Out:
# Total Features: 45
#
# First 20 Features:
# ['num__SeniorCitizen' 'num__tenure' 'num__MonthlyCharges'
#  'num__TotalCharges' 'cat__gender_Female' 'cat__gender_Male'
#  'cat__Partner_No' 'cat__Partner_Yes' 'cat__Dependents_No'
#  'cat__Dependents_Yes' 'cat__PhoneService_No' 'cat__PhoneService_Yes'
#  'cat__MultipleLines_No' 'cat__MultipleLines_No phone service'
#  'cat__MultipleLines_Yes' 'cat__InternetService_DSL'
#  'cat__InternetService_Fiber optic' 'cat__InternetService_No'
#  'cat__OnlineSecurity_No' 'cat__OnlineSecurity_No internet service']

# %%
import joblib

joblib.dump(
    preprocessor,
    r"C:\Users\SHIVANI\OneDrive\Attachments\ChurnGuard AI — Customer Churn Prediction & Retention System\models\preprocessor.pkl"
)

joblib.dump(
    feature_names,
    r"C:\Users\SHIVANI\OneDrive\Attachments\ChurnGuard AI — Customer Churn Prediction & Retention System\models\feature_columns.pkl"
)

print("Preprocessor saved successfully!")
# Out:
# Preprocessor saved successfully!

# %%
feature_names = preprocessor.get_feature_names_out()

print("Total Features:", len(feature_names))
print(feature_names)
# Out:
# Total Features: 45
# ['num__SeniorCitizen' 'num__tenure' 'num__MonthlyCharges'
#  'num__TotalCharges' 'cat__gender_Female' 'cat__gender_Male'
#  'cat__Partner_No' 'cat__Partner_Yes' 'cat__Dependents_No'
#  'cat__Dependents_Yes' 'cat__PhoneService_No' 'cat__PhoneService_Yes'
#  'cat__MultipleLines_No' 'cat__MultipleLines_No phone service'
#  'cat__MultipleLines_Yes' 'cat__InternetService_DSL'
#  'cat__InternetService_Fiber optic' 'cat__InternetService_No'
#  'cat__OnlineSecurity_No' 'cat__OnlineSecurity_No internet service'
#  'cat__OnlineSecurity_Yes' 'cat__OnlineBackup_No'
#  'cat__OnlineBackup_No internet service' 'cat__OnlineBackup_Yes'
#  'cat__DeviceProtection_No' 'cat__DeviceProtection_No internet service'
#  'cat__DeviceProtection_Yes' 'cat__TechSupport_No'
#  'cat__TechSupport_No internet service' 'cat__TechSupport_Yes'
#  'cat__StreamingTV_No' 'cat__StreamingTV_No internet service'
#  'cat__StreamingTV_Yes' 'cat__StreamingMovies_No'
# ...

# %%
X_train_df = pd.DataFrame(
    X_train_processed,
    columns=feature_names,
    index=X_train.index
)

X_test_df = pd.DataFrame(
    X_test_processed,
    columns=feature_names,
    index=X_test.index
)

print("X_train_df shape:", X_train_df.shape)
print("X_test_df shape:", X_test_df.shape)
# Out:
# X_train_df shape: (5616, 45)
# X_test_df shape: (1405, 45)

# %%
train_processed = X_train_df.copy()
train_processed["Churn"] = y_train.values

print(train_processed.shape)
# Out:
# (5616, 46)

# %%
test_processed = X_test_df.copy()
test_processed["Churn"] = y_test.values

print(test_processed.shape)
# Out:
# (1405, 46)

# %%
train_processed.to_csv(
    r"C:\Users\SHIVANI\OneDrive\Attachments\ChurnGuard AI — Customer Churn Prediction & Retention System\data\processed\pchurn_train_processed.csv",
    index=False
)

test_processed.to_csv(
    r"C:\Users\SHIVANI\OneDrive\Attachments\ChurnGuard AI — Customer Churn Prediction & Retention System\data\processed\pchurn_test_processed.csv",
    index=False
)

print("Processed train and test datasets saved successfully!")
# Out:
# Processed train and test datasets saved successfully!

# %%
import joblib

joblib.dump(
    preprocessor,
    r"C:\Users\SHIVANI\OneDrive\Attachments\ChurnGuard AI — Customer Churn Prediction & Retention System\models\preprocessor.pkl"
)

joblib.dump(
    feature_names.tolist(),
    r"C:\Users\SHIVANI\OneDrive\Attachments\ChurnGuard AI — Customer Churn Prediction & Retention System\models\feature_columns.pkl"
)

print("Preprocessor saved successfully!")
print("Feature columns saved successfully!")
# Out:
# Preprocessor saved successfully!
# Feature columns saved successfully!
